# %%
import json, os
import numpy as np
import requests as r
from glob import glob
from urllib.request import urlopen
from bs4 import BeautifulSoup
from datetime import datetime

# %%
fids = glob('*.dat')
latest_file = max(fids, key=os.path.getctime)
print(latest_file[:-4])
datetime.strptime(latest_file[:-4],'%Y-%m-%d_%H:%M:%S')
# Out:
# 2020-04-07_18:03:07
# datetime.datetime(2020, 4, 7, 18, 3, 7)

# %%
def download(LastUpdate):
    url = 'https://services7.arcgis.com/LXCny1HyhQCUSueu/ArcGIS/rest/services/' + \
          'Definitive_Healthcare_USA_Hospital_Beds/FeatureServer/0/query?where=0=0&outFields=*&f=pgeojson'
    html= r.get(url)
    html.encoding='utf-8'
    outfile = datetime.strftime(LastUpdate, '%Y-%m-%d_%H:%M:%S')
    with open(outfile+'.dat','w') as f:
        json.dump(html.json(),f)
    print(json.dumps(html.json(),indent=3))
        
def check_update(latest_file):
    url = 'https://services7.arcgis.com/LXCny1HyhQCUSueu/ArcGIS/rest/services/Definitive_Healthcare_USA_Hospital_Beds/FeatureServer/0'
    info = BeautifulSoup(urlopen(url))
    LastUpdate = [l for l in [l for l in info.get_text().split('\n') if l] if 'Last' in l][0].split(': ')[1]
    LastUpdate = datetime.strptime(LastUpdate,'%m/%d/%Y %I:%M:%S %p')
    PrevUpdate = datetime.strptime(latest_file[:-4],'%Y-%m-%d_%H:%M:%S')

    status = False if PrevUpdate == LastUpdate else LastUpdate.strftime('%Y-%m-%d_%H:%M:%S')
    if status:
        print('\n\n...New Update is processing...')
        print('...Date:{}...\n'.format(datetime.strftime(LastUpdate, '%Y-%m-%d_%H:%M:%S')))
        download(LastUpdate)

# %%
check_update(latest_file)
# Out:
# ...New Update is processing...
# ...Date:2020-04-07_18:03:07...
#
# {
#    "type": "FeatureCollection",
#    "properties": {
#       "exceededTransferLimit": true
#    },
#    "features": [
#       {
#          "type": "Feature",
#          "id": 1,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -112.0661569,
#                33.4954978000001
#             ]
#          },
#          "properties": {
#             "OBJECTID": 1,
#             "HOSPITAL_NAME": "Phoenix VA Health Care System (AKA Carl T Hayden VA Medical Center)",
#             "HOSPITAL_TYPE": "VA Hospital",
#             "HQ_ADDRESS": "650 E Indian School Rd",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Phoenix",
#             "HQ_STATE": "AZ",
#             "HQ_ZIP_CODE": "85012",
#             "COUNTY_NAME": "Maricopa",
#             "STATE_NAME": "Arizona",
#             "STATE_FIPS": "04",
#             "CNTY_FIPS": "013",
#             "FIPS": "04013",
#             "NUM_LICENSED_BEDS": 62,
#             "NUM_STAFFED_BEDS": 62,
#             "NUM_ICU_BEDS": 0,
#             "ADULT_ICU_BEDS": 0,
#             "PEDI_ICU_BEDS": null,
#             "BED_UTILIZATION": null,
#             "Potential_Increase_In_Bed_Capac": 0,
#             "AVG_VENTILATOR_USAGE": 0
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 2,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -110.9658852,
#                32.1812634
#             ]
#          },
#          "properties": {
#             "OBJECTID": 2,
#             "HOSPITAL_NAME": "Southern Arizona VA Health Care System",
#             "HOSPITAL_TYPE": "VA Hospital",
#             "HQ_ADDRESS": "3601 S 6th Ave",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Tucson",
#             "HQ_STATE": "AZ",
#             "HQ_ZIP_CODE": "85723",
#             "COUNTY_NAME": "Pima",
#             "STATE_NAME": "Arizona",
#             "STATE_FIPS": "04",
#             "CNTY_FIPS": "019",
#             "FIPS": "04019",
#             "NUM_LICENSED_BEDS": null,
#             "NUM_STAFFED_BEDS": null,
#             "NUM_ICU_BEDS": 2,
#             "ADULT_ICU_BEDS": 2,
#             "PEDI_ICU_BEDS": null,
#             "BED_UTILIZATION": null,
#             "Potential_Increase_In_Bed_Capac": 0,
#             "AVG_VENTILATOR_USAGE": 2
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 3,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -119.7797421,
#                36.7733235000001
#             ]
#          },
#          "properties": {
#             "OBJECTID": 3,
#             "HOSPITAL_NAME": "VA Central California Health Care System",
#             "HOSPITAL_TYPE": "VA Hospital",
#             "HQ_ADDRESS": "2615 E Clinton Ave",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Fresno",
#             "HQ_STATE": "CA",
#             "HQ_ZIP_CODE": "93703",
#             "COUNTY_NAME": "Fresno",
#             "STATE_NAME": "California",
#             "STATE_FIPS": "06",
#             "CNTY_FIPS": "019",
#             "FIPS": "06019",
#             "NUM_LICENSED_BEDS": null,
#             "NUM_STAFFED_BEDS": null,
#             "NUM_ICU_BEDS": 2,
#             "ADULT_ICU_BEDS": 2,
#             "PEDI_ICU_BEDS": null,
#             "BED_UTILIZATION": null,
#             "Potential_Increase_In_Bed_Capac": 0,
#             "AVG_VENTILATOR_USAGE": 2
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 4,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -72.9576102999999,
#                41.2844004
#             ]
#          },
#          "properties": {
#             "OBJECTID": 4,
#             "HOSPITAL_NAME": "VA Connecticut Healthcare System - West Haven Campus (AKA West Haven VA Medical Center)",
#             "HOSPITAL_TYPE": "VA Hospital",
#             "HQ_ADDRESS": "950 Campbell Ave",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "West Haven",
#             "HQ_STATE": "CT",
#             "HQ_ZIP_CODE": "06516",
#             "COUNTY_NAME": "New Haven",
#             "STATE_NAME": "Connecticut",
#             "STATE_FIPS": "09",
#             "CNTY_FIPS": "009",
#             "FIPS": "09009",
#             "NUM_LICENSED_BEDS": 216,
#             "NUM_STAFFED_BEDS": 216,
#             "NUM_ICU_BEDS": 1,
#             "ADULT_ICU_BEDS": 1,
#             "PEDI_ICU_BEDS": null,
#             "BED_UTILIZATION": null,
#             "Potential_Increase_In_Bed_Capac": 0,
#             "AVG_VENTILATOR_USAGE": 2
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 5,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -75.6065325,
#                39.7402063000001
#             ]
#          },
#          "properties": {
#             "OBJECTID": 5,
#             "HOSPITAL_NAME": "Wilmington VA Medical Center",
#             "HOSPITAL_TYPE": "VA Hospital",
#             "HQ_ADDRESS": "1601 Kirkwood Hwy",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Wilmington",
#             "HQ_STATE": "DE",
#             "HQ_ZIP_CODE": "19805",
#             "COUNTY_NAME": "New Castle",
#             "STATE_NAME": "Delaware",
#             "STATE_FIPS": "10",
#             "CNTY_FIPS": "003",
#             "FIPS": "10003",
#             "NUM_LICENSED_BEDS": null,
#             "NUM_STAFFED_BEDS": null,
#             "NUM_ICU_BEDS": 0,
#             "ADULT_ICU_BEDS": 0,
#             "PEDI_ICU_BEDS": null,
#             "BED_UTILIZATION": null,
#             "Potential_Increase_In_Bed_Capac": 0,
#             "AVG_VENTILATOR_USAGE": 1
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 6,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -77.0111947999999,
#                38.9306823000001
#             ]
#          },
#          "properties": {
#             "OBJECTID": 6,
#             "HOSPITAL_NAME": "Washington DC VA Medical Center",
#             "HOSPITAL_TYPE": "VA Hospital",
#             "HQ_ADDRESS": "50 Irving St Nw",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Washington",
#             "HQ_STATE": "DC",
#             "HQ_ZIP_CODE": "20422",
#             "COUNTY_NAME": "District of Columbia",
#             "STATE_NAME": "District of Columbia",
#             "STATE_FIPS": "11",
#             "CNTY_FIPS": "001",
#             "FIPS": "11001",
#             "NUM_LICENSED_BEDS": null,
#             "NUM_STAFFED_BEDS": null,
#             "NUM_ICU_BEDS": 1,
#             "ADULT_ICU_BEDS": 1,
#             "PEDI_ICU_BEDS": null,
#             "BED_UTILIZATION": null,
#             "Potential_Increase_In_Bed_Capac": 0,
#             "AVG_VENTILATOR_USAGE": 2
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 7,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -82.345254,
#                29.6369889000001
#             ]
#          },
#          "properties": {
#             "OBJECTID": 7,
#             "HOSPITAL_NAME": "North Florida/South Georgia Veterans Health System - Malcom Randall VA Medical Center",
#             "HOSPITAL_TYPE": "VA Hospital",
#             "HQ_ADDRESS": "1601 Sw Archer Rd",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Gainesville",
#             "HQ_STATE": "FL",
#             "HQ_ZIP_CODE": "32608",
#             "COUNTY_NAME": "Alachua",
#             "STATE_NAME": "Florida",
#             "STATE_FIPS": "12",
#             "CNTY_FIPS": "001",
#             "FIPS": "12001",
#             "NUM_LICENSED_BEDS": 432,
#             "NUM_STAFFED_BEDS": 278,
#             "NUM_ICU_BEDS": 2,
#             "ADULT_ICU_BEDS": 2,
#             "PEDI_ICU_BEDS": null,
#             "BED_UTILIZATION": null,
#             "Potential_Increase_In_Bed_Capac": 154,
#             "AVG_VENTILATOR_USAGE": 2
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 8,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -116.1901845,
#                43.6210350000001
#             ]
#          },
#          "properties": {
#             "OBJECTID": 8,
#             "HOSPITAL_NAME": "Boise VA Medical Center",
#             "HOSPITAL_TYPE": "VA Hospital",
#             "HQ_ADDRESS": "500 W Fort St",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Boise",
#             "HQ_STATE": "ID",
#             "HQ_ZIP_CODE": "83702",
#             "COUNTY_NAME": "Ada",
#             "STATE_NAME": "Idaho",
#             "STATE_FIPS": "16",
#             "CNTY_FIPS": "001",
#             "FIPS": "16001",
#             "NUM_LICENSED_BEDS": null,
#             "NUM_STAFFED_BEDS": null,
#             "NUM_ICU_BEDS": 1,
#             "ADULT_ICU_BEDS": 1,
#             "PEDI_ICU_BEDS": null,
#             "BED_UTILIZATION": null,
#             "Potential_Increase_In_Bed_Capac": 0,
#             "AVG_VENTILATOR_USAGE": 1
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 9,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -93.7216826,
#                32.5031008
#             ]
#          },
#          "properties": {
#             "OBJECTID": 9,
#             "HOSPITAL_NAME": "Overton Brooks VA Medical Center",
#             "HOSPITAL_TYPE": "VA Hospital",
#             "HQ_ADDRESS": "510 E Stoner Ave",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Shreveport",
#             "HQ_STATE": "LA",
#             "HQ_ZIP_CODE": "71101",
#             "COUNTY_NAME": "Caddo",
#             "STATE_NAME": "Louisiana",
#             "STATE_FIPS": "22",
#             "CNTY_FIPS": "017",
#             "FIPS": "22017",
#             "NUM_LICENSED_BEDS": null,
#             "NUM_STAFFED_BEDS": null,
#             "NUM_ICU_BEDS": 1,
#             "ADULT_ICU_BEDS": 1,
#             "PEDI_ICU_BEDS": null,
#             "BED_UTILIZATION": null,
#             "Potential_Increase_In_Bed_Capac": 0,
#             "AVG_VENTILATOR_USAGE": 2
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 10,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -90.1053085,
#                32.3254871
#             ]
#          },
#          "properties": {
#             "OBJECTID": 10,
#             "HOSPITAL_NAME": "Merit Health River Oaks (FKA River Oaks Hospital - Jackson)",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "1030 River Oaks Dr",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Flowood",
#             "HQ_STATE": "MS",
#             "HQ_ZIP_CODE": "39232",
#             "COUNTY_NAME": "Rankin",
#             "STATE_NAME": "Mississippi",
#             "STATE_FIPS": "28",
#             "CNTY_FIPS": "121",
#             "FIPS": "28121",
#             "NUM_LICENSED_BEDS": 160,
#             "NUM_STAFFED_BEDS": 160,
#             "NUM_ICU_BEDS": 10,
#             "ADULT_ICU_BEDS": 10,
#             "PEDI_ICU_BEDS": 20,
#             "BED_UTILIZATION": 0.2965667,
#             "Potential_Increase_In_Bed_Capac": 0,
#             "AVG_VENTILATOR_USAGE": 2
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 11,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -92.3288487,
#                38.9372354000001
#             ]
#          },
#          "properties": {
#             "OBJECTID": 11,
#             "HOSPITAL_NAME": "Harry S Truman Memorial Veterans Hospital",
#             "HOSPITAL_TYPE": "VA Hospital",
#             "HQ_ADDRESS": "800 Hospital Dr",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Columbia",
#             "HQ_STATE": "MO",
#             "HQ_ZIP_CODE": "65201",
#             "COUNTY_NAME": "Boone",
#             "STATE_NAME": "Missouri",
#             "STATE_FIPS": "29",
#             "CNTY_FIPS": "019",
#             "FIPS": "29019",
#             "NUM_LICENSED_BEDS": 89,
#             "NUM_STAFFED_BEDS": 89,
#             "NUM_ICU_BEDS": 2,
#             "ADULT_ICU_BEDS": 2,
#             "PEDI_ICU_BEDS": null,
#             "BED_UTILIZATION": null,
#             "Potential_Increase_In_Bed_Capac": 0,
#             "AVG_VENTILATOR_USAGE": 2
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 12,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -106.5816425,
#                35.0551931000001
#             ]
#          },
#          "properties": {
#             "OBJECTID": 12,
#             "HOSPITAL_NAME": "New Mexico VA Health Care System - Raymond G Murphy VA Medical Center",
#             "HOSPITAL_TYPE": "VA Hospital",
#             "HQ_ADDRESS": "1501 San Pedro Dr Se",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Albuquerque",
#             "HQ_STATE": "NM",
#             "HQ_ZIP_CODE": "87108",
#             "COUNTY_NAME": "Bernalillo",
#             "STATE_NAME": "New Mexico",
#             "STATE_FIPS": "35",
#             "CNTY_FIPS": "001",
#             "FIPS": "35001",
#             "NUM_LICENSED_BEDS": 163,
#             "NUM_STAFFED_BEDS": 163,
#             "NUM_ICU_BEDS": 1,
#             "ADULT_ICU_BEDS": 1,
#             "PEDI_ICU_BEDS": null,
#             "BED_UTILIZATION": null,
#             "Potential_Increase_In_Bed_Capac": 0,
#             "AVG_VENTILATOR_USAGE": 1
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 13,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -73.7744403999999,
#                42.6496127
#             ]
#          },
#          "properties": {
#             "OBJECTID": 13,
#             "HOSPITAL_NAME": "Albany Stratton VA Medical Center",
#             "HOSPITAL_TYPE": "VA Hospital",
#             "HQ_ADDRESS": "113 Holland Ave",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Albany",
#             "HQ_STATE": "NY",
#             "HQ_ZIP_CODE": "12208",
#             "COUNTY_NAME": "Albany",
#             "STATE_NAME": "New York",
#             "STATE_FIPS": "36",
#             "CNTY_FIPS": "001",
#             "FIPS": "36001",
#             "NUM_LICENSED_BEDS": 67,
#             "NUM_STAFFED_BEDS": 67,
#             "NUM_ICU_BEDS": 2,
#             "ADULT_ICU_BEDS": 2,
#             "PEDI_ICU_BEDS": null,
#             "BED_UTILIZATION": null,
#             "Potential_Increase_In_Bed_Capac": 0,
#             "AVG_VENTILATOR_USAGE": 2
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 14,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -73.9064046,
#                40.8674032000001
#             ]
#          },
#          "properties": {
#             "OBJECTID": 14,
#             "HOSPITAL_NAME": "James J Peters VA Medical Center",
#             "HOSPITAL_TYPE": "VA Hospital",
#             "HQ_ADDRESS": "130 W Kingsbridge Rd",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Bronx",
#             "HQ_STATE": "NY",
#             "HQ_ZIP_CODE": "10468",
#             "COUNTY_NAME": "Bronx",
#             "STATE_NAME": "New York",
#             "STATE_FIPS": "36",
#             "CNTY_FIPS": "005",
#             "FIPS": "36005",
#             "NUM_LICENSED_BEDS": null,
#             "NUM_STAFFED_BEDS": null,
#             "NUM_ICU_BEDS": 2,
#             "ADULT_ICU_BEDS": 2,
#             "PEDI_ICU_BEDS": null,
#             "BED_UTILIZATION": null,
#             "Potential_Increase_In_Bed_Capac": 0,
#             "AVG_VENTILATOR_USAGE": 2
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 15,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -96.77453,
#                46.9059328000001
#             ]
#          },
#          "properties": {
#             "OBJECTID": 15,
#             "HOSPITAL_NAME": "Fargo VA Health Care System",
#             "HOSPITAL_TYPE": "VA Hospital",
#             "HQ_ADDRESS": "2101 Elm St N",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Fargo",
#             "HQ_STATE": "ND",
#             "HQ_ZIP_CODE": "58102",
#             "COUNTY_NAME": "Cass",
#             "STATE_NAME": "North Dakota",
#             "STATE_FIPS": "38",
#             "CNTY_FIPS": "017",
#             "FIPS": "38017",
#             "NUM_LICENSED_BEDS": null,
#             "NUM_STAFFED_BEDS": null,
#             "NUM_ICU_BEDS": 1,
#             "ADULT_ICU_BEDS": 1,
#             "PEDI_ICU_BEDS": null,
#             "BED_UTILIZATION": null,
#             "Potential_Increase_In_Bed_Capac": 0,
#             "AVG_VENTILATOR_USAGE": 1
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 16,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -123.3650574,
#                43.2270692000001
#             ]
#          },
#          "properties": {
#             "OBJECTID": 16,
#             "HOSPITAL_NAME": "Roseburg VA Health Care System",
#             "HOSPITAL_TYPE": "VA Hospital",
#             "HQ_ADDRESS": "913 Nw Garden Valley Blvd",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Roseburg",
#             "HQ_STATE": "OR",
#             "HQ_ZIP_CODE": "97471",
#             "COUNTY_NAME": "Douglas",
#             "STATE_NAME": "Oregon",
#             "STATE_FIPS": "41",
#             "CNTY_FIPS": "019",
#             "FIPS": "41019",
#             "NUM_LICENSED_BEDS": null,
#             "NUM_STAFFED_BEDS": null,
#             "NUM_ICU_BEDS": 0,
#             "ADULT_ICU_BEDS": 0,
#             "PEDI_ICU_BEDS": null,
#             "BED_UTILIZATION": null,
#             "Potential_Increase_In_Bed_Capac": 0,
#             "AVG_VENTILATOR_USAGE": 0
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 17,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -79.9608074,
#                40.4462661000001
#             ]
#          },
#          "properties": {
#             "OBJECTID": 17,
#             "HOSPITAL_NAME": "VA Pittsburgh Healthcare System - University Drive",
#             "HOSPITAL_TYPE": "VA Hospital",
#             "HQ_ADDRESS": "4100 Allequippa St",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Pittsburgh",
#             "HQ_STATE": "PA",
#             "HQ_ZIP_CODE": "15219",
#             "COUNTY_NAME": "Allegheny",
#             "STATE_NAME": "Pennsylvania",
#             "STATE_FIPS": "42",
#             "CNTY_FIPS": "003",
#             "FIPS": "42003",
#             "NUM_LICENSED_BEDS": 146,
#             "NUM_STAFFED_BEDS": 146,
#             "NUM_ICU_BEDS": 2,
#             "ADULT_ICU_BEDS": 2,
#             "PEDI_ICU_BEDS": null,
#             "BED_UTILIZATION": null,
#             "Potential_Increase_In_Bed_Capac": 0,
#             "AVG_VENTILATOR_USAGE": 2
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 18,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -86.451938,
#                32.463778
#             ]
#          },
#          "properties": {
#             "OBJECTID": 18,
#             "HOSPITAL_NAME": "Prattville Baptist Hospital",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "124 S Memorial Dr",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Prattville",
#             "HQ_STATE": "AL",
#             "HQ_ZIP_CODE": "36067",
#             "COUNTY_NAME": "Autauga",
#             "STATE_NAME": "Alabama",
#             "STATE_FIPS": "01",
#             "CNTY_FIPS": "001",
#             "FIPS": "01001",
#             "NUM_LICENSED_BEDS": 85,
#             "NUM_STAFFED_BEDS": 55,
#             "NUM_ICU_BEDS": 6,
#             "ADULT_ICU_BEDS": 6,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.6231133,
#             "Potential_Increase_In_Bed_Capac": 30,
#             "AVG_VENTILATOR_USAGE": 2
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 19,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -87.8883067,
#                30.5190265000001
#             ]
#          },
#          "properties": {
#             "OBJECTID": 19,
#             "HOSPITAL_NAME": "Thomas Hospital",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "750 Morphy Ave",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Fairhope",
#             "HQ_STATE": "AL",
#             "HQ_ZIP_CODE": "36532",
#             "COUNTY_NAME": "Baldwin",
#             "STATE_NAME": "Alabama",
#             "STATE_FIPS": "01",
#             "CNTY_FIPS": "003",
#             "FIPS": "01003",
#             "NUM_LICENSED_BEDS": 150,
#             "NUM_STAFFED_BEDS": 129,
#             "NUM_ICU_BEDS": 17,
#             "ADULT_ICU_BEDS": 17,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.7700542,
#             "Potential_Increase_In_Bed_Capac": 21,
#             "AVG_VENTILATOR_USAGE": 3
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 20,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -87.785172,
#                30.9039450000001
#             ]
#          },
#          "properties": {
#             "OBJECTID": 20,
#             "HOSPITAL_NAME": "North Baldwin Infirmary",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "1815 Hand Ave",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Bay Minette",
#             "HQ_STATE": "AL",
#             "HQ_ZIP_CODE": "36507",
#             "COUNTY_NAME": "Baldwin",
#             "STATE_NAME": "Alabama",
#             "STATE_FIPS": "01",
#             "CNTY_FIPS": "003",
#             "FIPS": "01003",
#             "NUM_LICENSED_BEDS": 58,
#             "NUM_STAFFED_BEDS": 55,
#             "NUM_ICU_BEDS": 4,
#             "ADULT_ICU_BEDS": 4,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.2851308,
#             "Potential_Increase_In_Bed_Capac": 3,
#             "AVG_VENTILATOR_USAGE": 2
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 21,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -85.1563565,
#                31.8887641000001
#             ]
#          },
#          "properties": {
#             "OBJECTID": 21,
#             "HOSPITAL_NAME": "Medical Center Barbour",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "820 W Washington St",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Eufaula",
#             "HQ_STATE": "AL",
#             "HQ_ZIP_CODE": "36027",
#             "COUNTY_NAME": "Barbour",
#             "STATE_NAME": "Alabama",
#             "STATE_FIPS": "01",
#             "CNTY_FIPS": "005",
#             "FIPS": "01005",
#             "NUM_LICENSED_BEDS": 74,
#             "NUM_STAFFED_BEDS": 30,
#             "NUM_ICU_BEDS": 5,
#             "ADULT_ICU_BEDS": 5,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.4306397,
#             "Potential_Increase_In_Bed_Capac": 44,
#             "AVG_VENTILATOR_USAGE": 2
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 22,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -87.1481335999999,
#                32.9512234000001
#             ]
#          },
#          "properties": {
#             "OBJECTID": 22,
#             "HOSPITAL_NAME": "Bibb Medical Center",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "208 Pierson Ave",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Centreville",
#             "HQ_STATE": "AL",
#             "HQ_ZIP_CODE": "35042",
#             "COUNTY_NAME": "Bibb",
#             "STATE_NAME": "Alabama",
#             "STATE_FIPS": "01",
#             "CNTY_FIPS": "007",
#             "FIPS": "01007",
#             "NUM_LICENSED_BEDS": 35,
#             "NUM_STAFFED_BEDS": 25,
#             "NUM_ICU_BEDS": 4,
#             "ADULT_ICU_BEDS": 4,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.3762192,
#             "Potential_Increase_In_Bed_Capac": 10,
#             "AVG_VENTILATOR_USAGE": 1
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 23,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -86.4949953,
#                33.9333028
#             ]
#          },
#          "properties": {
#             "OBJECTID": 23,
#             "HOSPITAL_NAME": "St Vincents Blount",
#             "HOSPITAL_TYPE": "Critical Access Hospital",
#             "HQ_ADDRESS": "150 Gilbreath Dr",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Oneonta",
#             "HQ_STATE": "AL",
#             "HQ_ZIP_CODE": "35121",
#             "COUNTY_NAME": "Blount",
#             "STATE_NAME": "Alabama",
#             "STATE_FIPS": "01",
#             "CNTY_FIPS": "009",
#             "FIPS": "01009",
#             "NUM_LICENSED_BEDS": 25,
#             "NUM_STAFFED_BEDS": 25,
#             "NUM_ICU_BEDS": 6,
#             "ADULT_ICU_BEDS": 6,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.4990685,
#             "Potential_Increase_In_Bed_Capac": 0,
#             "AVG_VENTILATOR_USAGE": 2
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 24,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -85.713048,
#                32.1461190000001
#             ]
#          },
#          "properties": {
#             "OBJECTID": 24,
#             "HOSPITAL_NAME": "Bullock County Hospital",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "102 Conecuh Ave W",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Union Springs",
#             "HQ_STATE": "AL",
#             "HQ_ZIP_CODE": "36089",
#             "COUNTY_NAME": "Bullock",
#             "STATE_NAME": "Alabama",
#             "STATE_FIPS": "01",
#             "CNTY_FIPS": "011",
#             "FIPS": "01011",
#             "NUM_LICENSED_BEDS": 61,
#             "NUM_STAFFED_BEDS": 30,
#             "NUM_ICU_BEDS": 5,
#             "ADULT_ICU_BEDS": 5,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.2128767,
#             "Potential_Increase_In_Bed_Capac": 31,
#             "AVG_VENTILATOR_USAGE": 1
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 25,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -86.64627,
#                31.8290939
#             ]
#          },
#          "properties": {
#             "OBJECTID": 25,
#             "HOSPITAL_NAME": "Regional Medical Center of Central Alabama (FKA LV Stabler Memorial Hospital)",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "29 L V Stabler Dr",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Greenville",
#             "HQ_STATE": "AL",
#             "HQ_ZIP_CODE": "36037",
#             "COUNTY_NAME": "Butler",
#             "STATE_NAME": "Alabama",
#             "STATE_FIPS": "01",
#             "CNTY_FIPS": "013",
#             "FIPS": "01013",
#             "NUM_LICENSED_BEDS": 72,
#             "NUM_STAFFED_BEDS": 44,
#             "NUM_ICU_BEDS": 7,
#             "ADULT_ICU_BEDS": 7,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.1832514,
#             "Potential_Increase_In_Bed_Capac": 28,
#             "AVG_VENTILATOR_USAGE": 2
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 26,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -85.825,
#                33.6676000000001
#             ]
#          },
#          "properties": {
#             "OBJECTID": 26,
#             "HOSPITAL_NAME": "Stringfellow Memorial Hospital",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "301 E 18th St",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Anniston",
#             "HQ_STATE": "AL",
#             "HQ_ZIP_CODE": "36207",
#             "COUNTY_NAME": "Calhoun",
#             "STATE_NAME": "Alabama",
#             "STATE_FIPS": "01",
#             "CNTY_FIPS": "015",
#             "FIPS": "01015",
#             "NUM_LICENSED_BEDS": 125,
#             "NUM_STAFFED_BEDS": 125,
#             "NUM_ICU_BEDS": 6,
#             "ADULT_ICU_BEDS": 6,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.2222904,
#             "Potential_Increase_In_Bed_Capac": 0,
#             "AVG_VENTILATOR_USAGE": 2
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 27,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -85.8228352,
#                33.6563953
#             ]
#          },
#          "properties": {
#             "OBJECTID": 27,
#             "HOSPITAL_NAME": "Regional Medical Center Anniston (FKA Northeast Alabama Regional Medical Center - Anniston)",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "400 E 10th St",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Anniston",
#             "HQ_STATE": "AL",
#             "HQ_ZIP_CODE": "36207",
#             "COUNTY_NAME": "Calhoun",
#             "STATE_NAME": "Alabama",
#             "STATE_FIPS": "01",
#             "CNTY_FIPS": "015",
#             "FIPS": "01015",
#             "NUM_LICENSED_BEDS": 323,
#             "NUM_STAFFED_BEDS": 250,
#             "NUM_ICU_BEDS": 18,
#             "ADULT_ICU_BEDS": 18,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.5867507,
#             "Potential_Increase_In_Bed_Capac": 73,
#             "AVG_VENTILATOR_USAGE": 11
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 28,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -85.1685934,
#                32.8246478
#             ]
#          },
#          "properties": {
#             "OBJECTID": 28,
#             "HOSPITAL_NAME": "East Alabama Medical Center - Lanier",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "4800 48th St",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Valley",
#             "HQ_STATE": "AL",
#             "HQ_ZIP_CODE": "36854",
#             "COUNTY_NAME": "Chambers",
#             "STATE_NAME": "Alabama",
#             "STATE_FIPS": "01",
#             "CNTY_FIPS": "017",
#             "FIPS": "01017",
#             "NUM_LICENSED_BEDS": 115,
#             "NUM_STAFFED_BEDS": null,
#             "NUM_ICU_BEDS": 15,
#             "ADULT_ICU_BEDS": 15,
#             "PEDI_ICU_BEDS": null,
#             "BED_UTILIZATION": null,
#             "Potential_Increase_In_Bed_Capac": 115,
#             "AVG_VENTILATOR_USAGE": 0
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 29,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -85.6512999999999,
#                34.1627
#             ]
#          },
#          "properties": {
#             "OBJECTID": 29,
#             "HOSPITAL_NAME": "Cherokee Medical Center",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "400 Northwood Dr",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Centre",
#             "HQ_STATE": "AL",
#             "HQ_ZIP_CODE": "35960",
#             "COUNTY_NAME": "Cherokee",
#             "STATE_NAME": "Alabama",
#             "STATE_FIPS": "01",
#             "CNTY_FIPS": "019",
#             "FIPS": "01019",
#             "NUM_LICENSED_BEDS": 60,
#             "NUM_STAFFED_BEDS": 45,
#             "NUM_ICU_BEDS": 8,
#             "ADULT_ICU_BEDS": 8,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.2425316,
#             "Potential_Increase_In_Bed_Capac": 15,
#             "AVG_VENTILATOR_USAGE": 1
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 30,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -87.7772891,
#                31.695007
#             ]
#          },
#          "properties": {
#             "OBJECTID": 30,
#             "HOSPITAL_NAME": "Grove Hill Memorial Hospital",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "295 S Jackson St",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Grove Hill",
#             "HQ_STATE": "AL",
#             "HQ_ZIP_CODE": "36451",
#             "COUNTY_NAME": "Clarke",
#             "STATE_NAME": "Alabama",
#             "STATE_FIPS": "01",
#             "CNTY_FIPS": "025",
#             "FIPS": "01025",
#             "NUM_LICENSED_BEDS": 50,
#             "NUM_STAFFED_BEDS": 21,
#             "NUM_ICU_BEDS": 4,
#             "ADULT_ICU_BEDS": 4,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.3127201,
#             "Potential_Increase_In_Bed_Capac": 29,
#             "AVG_VENTILATOR_USAGE": 1
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 31,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -87.895053,
#                31.5311947000001
#             ]
#          },
#          "properties": {
#             "OBJECTID": 31,
#             "HOSPITAL_NAME": "Jackson Medical Center",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "220 Hospital Dr",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Jackson",
#             "HQ_STATE": "AL",
#             "HQ_ZIP_CODE": "36545",
#             "COUNTY_NAME": "Clarke",
#             "STATE_NAME": "Alabama",
#             "STATE_FIPS": "01",
#             "CNTY_FIPS": "025",
#             "FIPS": "01025",
#             "NUM_LICENSED_BEDS": 35,
#             "NUM_STAFFED_BEDS": 35,
#             "NUM_ICU_BEDS": 6,
#             "ADULT_ICU_BEDS": 6,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.2668493,
#             "Potential_Increase_In_Bed_Capac": 0,
#             "AVG_VENTILATOR_USAGE": 1
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 32,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -85.823822,
#                33.2771472000001
#             ]
#          },
#          "properties": {
#             "OBJECTID": 32,
#             "HOSPITAL_NAME": "Clay County Hospital",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "83825 Highway 9",
#             "HQ_ADDRESS1": "PO BOX 1270",
#             "HQ_CITY": "Ashland",
#             "HQ_STATE": "AL",
#             "HQ_ZIP_CODE": "36251",
#             "COUNTY_NAME": "Clay",
#             "STATE_NAME": "Alabama",
#             "STATE_FIPS": "01",
#             "CNTY_FIPS": "027",
#             "FIPS": "01027",
#             "NUM_LICENSED_BEDS": 45,
#             "NUM_STAFFED_BEDS": 46,
#             "NUM_ICU_BEDS": 4,
#             "ADULT_ICU_BEDS": 4,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.2911257,
#             "Potential_Increase_In_Bed_Capac": -1,
#             "AVG_VENTILATOR_USAGE": 2
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 33,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -85.855114,
#                31.3186470000001
#             ]
#          },
#          "properties": {
#             "OBJECTID": 33,
#             "HOSPITAL_NAME": "Medical Center Enterprise",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "400 N Edwards St",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Enterprise",
#             "HQ_STATE": "AL",
#             "HQ_ZIP_CODE": "36330",
#             "COUNTY_NAME": "Coffee",
#             "STATE_NAME": "Alabama",
#             "STATE_FIPS": "01",
#             "CNTY_FIPS": "031",
#             "FIPS": "01031",
#             "NUM_LICENSED_BEDS": 131,
#             "NUM_STAFFED_BEDS": 99,
#             "NUM_ICU_BEDS": 7,
#             "ADULT_ICU_BEDS": 7,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.2380518,
#             "Potential_Increase_In_Bed_Capac": 32,
#             "AVG_VENTILATOR_USAGE": 2
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 34,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -87.675383,
#                34.744969
#             ]
#          },
#          "properties": {
#             "OBJECTID": 34,
#             "HOSPITAL_NAME": "Shoals Hospital",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "201 Avalon Ave",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Muscle Shoals",
#             "HQ_STATE": "AL",
#             "HQ_ZIP_CODE": "35661",
#             "COUNTY_NAME": "Colbert",
#             "STATE_NAME": "Alabama",
#             "STATE_FIPS": "01",
#             "CNTY_FIPS": "033",
#             "FIPS": "01033",
#             "NUM_LICENSED_BEDS": 198,
#             "NUM_STAFFED_BEDS": 122,
#             "NUM_ICU_BEDS": 10,
#             "ADULT_ICU_BEDS": 10,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.1223445,
#             "Potential_Increase_In_Bed_Capac": 76,
#             "AVG_VENTILATOR_USAGE": 2
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 35,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -86.9408213,
#                31.4309781000001
#             ]
#          },
#          "properties": {
#             "OBJECTID": 35,
#             "HOSPITAL_NAME": "Evergreen Medical Center",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "101 Crestview Ave",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Evergreen",
#             "HQ_STATE": "AL",
#             "HQ_ZIP_CODE": "36401",
#             "COUNTY_NAME": "Conecuh",
#             "STATE_NAME": "Alabama",
#             "STATE_FIPS": "01",
#             "CNTY_FIPS": "035",
#             "FIPS": "01035",
#             "NUM_LICENSED_BEDS": 58,
#             "NUM_STAFFED_BEDS": 44,
#             "NUM_ICU_BEDS": 8,
#             "ADULT_ICU_BEDS": 8,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.2938356,
#             "Potential_Increase_In_Bed_Capac": 14,
#             "AVG_VENTILATOR_USAGE": 0
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 36,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -86.4947624,
#                31.2962978
#             ]
#          },
#          "properties": {
#             "OBJECTID": 36,
#             "HOSPITAL_NAME": "Andalusia Regional Hospital (AKA Andalusia Health)",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "849 S Three Notch St",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Andalusia",
#             "HQ_STATE": "AL",
#             "HQ_ZIP_CODE": "36420",
#             "COUNTY_NAME": "Covington",
#             "STATE_NAME": "Alabama",
#             "STATE_FIPS": "01",
#             "CNTY_FIPS": "039",
#             "FIPS": "01039",
#             "NUM_LICENSED_BEDS": 88,
#             "NUM_STAFFED_BEDS": 83,
#             "NUM_ICU_BEDS": 8,
#             "ADULT_ICU_BEDS": 8,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.3337184,
#             "Potential_Increase_In_Bed_Capac": 5,
#             "AVG_VENTILATOR_USAGE": 2
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 37,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -86.2542061999999,
#                31.2919852000001
#             ]
#          },
#          "properties": {
#             "OBJECTID": 37,
#             "HOSPITAL_NAME": "Mizell Memorial Hospital",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "702 N Main St",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Opp",
#             "HQ_STATE": "AL",
#             "HQ_ZIP_CODE": "36467",
#             "COUNTY_NAME": "Covington",
#             "STATE_NAME": "Alabama",
#             "STATE_FIPS": "01",
#             "CNTY_FIPS": "039",
#             "FIPS": "01039",
#             "NUM_LICENSED_BEDS": 99,
#             "NUM_STAFFED_BEDS": 45,
#             "NUM_ICU_BEDS": 5,
#             "ADULT_ICU_BEDS": 5,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.2782953,
#             "Potential_Increase_In_Bed_Capac": 54,
#             "AVG_VENTILATOR_USAGE": 2
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 38,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -86.2650940999999,
#                31.6933529
#             ]
#          },
#          "properties": {
#             "OBJECTID": 38,
#             "HOSPITAL_NAME": "Crenshaw Community Hospital",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "101 Hospital Dr",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Luverne",
#             "HQ_STATE": "AL",
#             "HQ_ZIP_CODE": "36049",
#             "COUNTY_NAME": "Crenshaw",
#             "STATE_NAME": "Alabama",
#             "STATE_FIPS": "01",
#             "CNTY_FIPS": "041",
#             "FIPS": "01041",
#             "NUM_LICENSED_BEDS": 65,
#             "NUM_STAFFED_BEDS": 29,
#             "NUM_ICU_BEDS": 5,
#             "ADULT_ICU_BEDS": 5,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.1260274,
#             "Potential_Increase_In_Bed_Capac": 36,
#             "AVG_VENTILATOR_USAGE": 2
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 39,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -86.8748530999999,
#                34.2075866000001
#             ]
#          },
#          "properties": {
#             "OBJECTID": 39,
#             "HOSPITAL_NAME": "Cullman Regional Medical Center",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "1912 Alabama Hwy 157",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Cullman",
#             "HQ_STATE": "AL",
#             "HQ_ZIP_CODE": "35058",
#             "COUNTY_NAME": "Cullman",
#             "STATE_NAME": "Alabama",
#             "STATE_FIPS": "01",
#             "CNTY_FIPS": "043",
#             "FIPS": "01043",
#             "NUM_LICENSED_BEDS": 145,
#             "NUM_STAFFED_BEDS": 145,
#             "NUM_ICU_BEDS": 12,
#             "ADULT_ICU_BEDS": 12,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.5081719,
#             "Potential_Increase_In_Bed_Capac": 0,
#             "AVG_VENTILATOR_USAGE": 5
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 40,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -85.632075,
#                31.451328
#             ]
#          },
#          "properties": {
#             "OBJECTID": 40,
#             "HOSPITAL_NAME": "Dale Medical Center",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "126 Hospital Ave",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Ozark",
#             "HQ_STATE": "AL",
#             "HQ_ZIP_CODE": "36360",
#             "COUNTY_NAME": "Dale",
#             "STATE_NAME": "Alabama",
#             "STATE_FIPS": "01",
#             "CNTY_FIPS": "045",
#             "FIPS": "01045",
#             "NUM_LICENSED_BEDS": 89,
#             "NUM_STAFFED_BEDS": 77,
#             "NUM_ICU_BEDS": 6,
#             "ADULT_ICU_BEDS": 6,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.2882405,
#             "Potential_Increase_In_Bed_Capac": 12,
#             "AVG_VENTILATOR_USAGE": 2
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 41,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -87.056025,
#                32.4292722000001
#             ]
#          },
#          "properties": {
#             "OBJECTID": 41,
#             "HOSPITAL_NAME": "Vaughan Regional Medical Center",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "1015 Medical Center Pkwy",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Selma",
#             "HQ_STATE": "AL",
#             "HQ_ZIP_CODE": "36701",
#             "COUNTY_NAME": "Dallas",
#             "STATE_NAME": "Alabama",
#             "STATE_FIPS": "01",
#             "CNTY_FIPS": "047",
#             "FIPS": "01047",
#             "NUM_LICENSED_BEDS": 175,
#             "NUM_STAFFED_BEDS": 109,
#             "NUM_ICU_BEDS": 23,
#             "ADULT_ICU_BEDS": 23,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.4045997,
#             "Potential_Increase_In_Bed_Capac": 66,
#             "AVG_VENTILATOR_USAGE": 2
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 42,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -85.7550138,
#                34.4419753
#             ]
#          },
#          "properties": {
#             "OBJECTID": 42,
#             "HOSPITAL_NAME": "Dekalb Regional Medical Center",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "200 Medical Center Dr",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Fort Payne",
#             "HQ_STATE": "AL",
#             "HQ_ZIP_CODE": "35968",
#             "COUNTY_NAME": "DeKalb",
#             "STATE_NAME": "Alabama",
#             "STATE_FIPS": "01",
#             "CNTY_FIPS": "049",
#             "FIPS": "01049",
#             "NUM_LICENSED_BEDS": 134,
#             "NUM_STAFFED_BEDS": 97,
#             "NUM_ICU_BEDS": 12,
#             "ADULT_ICU_BEDS": 12,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.2922186,
#             "Potential_Increase_In_Bed_Capac": 37,
#             "AVG_VENTILATOR_USAGE": 3
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 43,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -85.912363,
#                32.534053
#             ]
#          },
#          "properties": {
#             "OBJECTID": 43,
#             "HOSPITAL_NAME": "Community Hospital",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "805 Friendship Rd",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Tallassee",
#             "HQ_STATE": "AL",
#             "HQ_ZIP_CODE": "36078",
#             "COUNTY_NAME": "Elmore",
#             "STATE_NAME": "Alabama",
#             "STATE_FIPS": "01",
#             "CNTY_FIPS": "051",
#             "FIPS": "01051",
#             "NUM_LICENSED_BEDS": 69,
#             "NUM_STAFFED_BEDS": 37,
#             "NUM_ICU_BEDS": 5,
#             "ADULT_ICU_BEDS": 5,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.3637912,
#             "Potential_Increase_In_Bed_Capac": 32,
#             "AVG_VENTILATOR_USAGE": 2
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 44,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -86.1866697,
#                32.5523787000001
#             ]
#          },
#          "properties": {
#             "OBJECTID": 44,
#             "HOSPITAL_NAME": "Elmore Community Hospital",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "500 Hospital Dr",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Wetumpka",
#             "HQ_STATE": "AL",
#             "HQ_ZIP_CODE": "36092",
#             "COUNTY_NAME": "Elmore",
#             "STATE_NAME": "Alabama",
#             "STATE_FIPS": "01",
#             "CNTY_FIPS": "051",
#             "FIPS": "01051",
#             "NUM_LICENSED_BEDS": 69,
#             "NUM_STAFFED_BEDS": 33,
#             "NUM_ICU_BEDS": 6,
#             "ADULT_ICU_BEDS": 6,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.298049,
#             "Potential_Increase_In_Bed_Capac": 36,
#             "AVG_VENTILATOR_USAGE": 1
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 45,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -87.0712,
#                31.1249
#             ]
#          },
#          "properties": {
#             "OBJECTID": 45,
#             "HOSPITAL_NAME": "DW McMillan Memorial Hospital",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "1301 Belleville Ave",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Brewton",
#             "HQ_STATE": "AL",
#             "HQ_ZIP_CODE": "36426",
#             "COUNTY_NAME": "Escambia",
#             "STATE_NAME": "Alabama",
#             "STATE_FIPS": "01",
#             "CNTY_FIPS": "053",
#             "FIPS": "01053",
#             "NUM_LICENSED_BEDS": 91,
#             "NUM_STAFFED_BEDS": 46,
#             "NUM_ICU_BEDS": 8,
# ...
#             "HOSPITAL_NAME": "Cass Lake Indian Health Service Unit (AKA Cass Lake Hospital)",
#             "HOSPITAL_TYPE": "Critical Access Hospital",
#             "HQ_ADDRESS": "425 7th St Nw",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Cass Lake",
#             "HQ_STATE": "MN",
#             "HQ_ZIP_CODE": "56633",
#             "COUNTY_NAME": "Cass",
#             "STATE_NAME": "Minnesota",
#             "STATE_FIPS": "27",
#             "CNTY_FIPS": "021",
#             "FIPS": "27021",
#             "NUM_LICENSED_BEDS": 5,
#             "NUM_STAFFED_BEDS": 5,
#             "NUM_ICU_BEDS": 1,
#             "ADULT_ICU_BEDS": 1,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.01260274,
#             "Potential_Increase_In_Bed_Capac": 0,
#             "AVG_VENTILATOR_USAGE": 0
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 1987,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -95.7116947,
#                44.9529596
#             ]
#          },
#          "properties": {
#             "OBJECTID": 1987,
#             "HOSPITAL_NAME": "CCM Health (FKA Chippewa County Montevideo Hospital)",
#             "HOSPITAL_TYPE": "Critical Access Hospital",
#             "HQ_ADDRESS": "824 N 11th St",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Montevideo",
#             "HQ_STATE": "MN",
#             "HQ_ZIP_CODE": "56265",
#             "COUNTY_NAME": "Chippewa",
#             "STATE_NAME": "Minnesota",
#             "STATE_FIPS": "27",
#             "CNTY_FIPS": "023",
#             "FIPS": "27023",
#             "NUM_LICENSED_BEDS": 30,
#             "NUM_STAFFED_BEDS": 25,
#             "NUM_ICU_BEDS": 4,
#             "ADULT_ICU_BEDS": 4,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.2286027,
#             "Potential_Increase_In_Bed_Capac": 5,
#             "AVG_VENTILATOR_USAGE": 2
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 1988,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -93.000552,
#                45.3218708000001
#             ]
#          },
#          "properties": {
#             "OBJECTID": 1988,
#             "HOSPITAL_NAME": "M Health Fairview Lakes Medical Center",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "5200 Fairview Blvd",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Wyoming",
#             "HQ_STATE": "MN",
#             "HQ_ZIP_CODE": "55092",
#             "COUNTY_NAME": "Chisago",
#             "STATE_NAME": "Minnesota",
#             "STATE_FIPS": "27",
#             "CNTY_FIPS": "025",
#             "FIPS": "27025",
#             "NUM_LICENSED_BEDS": 61,
#             "NUM_STAFFED_BEDS": 55,
#             "NUM_ICU_BEDS": 10,
#             "ADULT_ICU_BEDS": 10,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.4464757,
#             "Potential_Increase_In_Bed_Capac": 6,
#             "AVG_VENTILATOR_USAGE": 2
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 1989,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -95.4393322,
#                44.0454324
#             ]
#          },
#          "properties": {
#             "OBJECTID": 1989,
#             "HOSPITAL_NAME": "Sanford Westbrook Medical Center",
#             "HOSPITAL_TYPE": "Critical Access Hospital",
#             "HQ_ADDRESS": "920 Bell Ave",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Westbrook",
#             "HQ_STATE": "MN",
#             "HQ_ZIP_CODE": "56183",
#             "COUNTY_NAME": "Cottonwood",
#             "STATE_NAME": "Minnesota",
#             "STATE_FIPS": "27",
#             "CNTY_FIPS": "033",
#             "FIPS": "27033",
#             "NUM_LICENSED_BEDS": 8,
#             "NUM_STAFFED_BEDS": 8,
#             "NUM_ICU_BEDS": 1,
#             "ADULT_ICU_BEDS": 1,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.1123288,
#             "Potential_Increase_In_Bed_Capac": 0,
#             "AVG_VENTILATOR_USAGE": 0
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 1990,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -95.1130803,
#                43.8794277000001
#             ]
#          },
#          "properties": {
#             "OBJECTID": 1990,
#             "HOSPITAL_NAME": "Windom Area Health (AKA Windom Area Hospital)",
#             "HOSPITAL_TYPE": "Critical Access Hospital",
#             "HQ_ADDRESS": "2150 Hospital Dr",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Windom",
#             "HQ_STATE": "MN",
#             "HQ_ZIP_CODE": "56101",
#             "COUNTY_NAME": "Cottonwood",
#             "STATE_NAME": "Minnesota",
#             "STATE_FIPS": "27",
#             "CNTY_FIPS": "033",
#             "FIPS": "27033",
#             "NUM_LICENSED_BEDS": 18,
#             "NUM_STAFFED_BEDS": 18,
#             "NUM_ICU_BEDS": 3,
#             "ADULT_ICU_BEDS": 3,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.1805175,
#             "Potential_Increase_In_Bed_Capac": 0,
#             "AVG_VENTILATOR_USAGE": 0
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 1991,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -93.945304,
#                46.4815609
#             ]
#          },
#          "properties": {
#             "OBJECTID": 1991,
#             "HOSPITAL_NAME": "Cuyuna Regional Medical Center - Crosby",
#             "HOSPITAL_TYPE": "Critical Access Hospital",
#             "HQ_ADDRESS": "320 E Main St",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Crosby",
#             "HQ_STATE": "MN",
#             "HQ_ZIP_CODE": "56441",
#             "COUNTY_NAME": "Crow Wing",
#             "STATE_NAME": "Minnesota",
#             "STATE_FIPS": "27",
#             "CNTY_FIPS": "035",
#             "FIPS": "27035",
#             "NUM_LICENSED_BEDS": 42,
#             "NUM_STAFFED_BEDS": 25,
#             "NUM_ICU_BEDS": 6,
#             "ADULT_ICU_BEDS": 6,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.4414247,
#             "Potential_Increase_In_Bed_Capac": 17,
#             "AVG_VENTILATOR_USAGE": 2
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 1992,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -94.205733,
#                46.361656
#             ]
#          },
#          "properties": {
#             "OBJECTID": 1992,
#             "HOSPITAL_NAME": "Essentia Health - St Josephs Medical Center (FKA St Josephs Medical Center)",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "523 N 3rd St",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Brainerd",
#             "HQ_STATE": "MN",
#             "HQ_ZIP_CODE": "56401",
#             "COUNTY_NAME": "Crow Wing",
#             "STATE_NAME": "Minnesota",
#             "STATE_FIPS": "27",
#             "CNTY_FIPS": "035",
#             "FIPS": "27035",
#             "NUM_LICENSED_BEDS": 162,
#             "NUM_STAFFED_BEDS": 127,
#             "NUM_ICU_BEDS": 10,
#             "ADULT_ICU_BEDS": 10,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.4042498,
#             "Potential_Increase_In_Bed_Capac": 35,
#             "AVG_VENTILATOR_USAGE": 3
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 1993,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -92.8731423999999,
#                44.747369
#             ]
#          },
#          "properties": {
#             "OBJECTID": 1993,
#             "HOSPITAL_NAME": "Regina Hospital",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "1175 Nininger Rd",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Hastings",
#             "HQ_STATE": "MN",
#             "HQ_ZIP_CODE": "55033",
#             "COUNTY_NAME": "Dakota",
#             "STATE_NAME": "Minnesota",
#             "STATE_FIPS": "27",
#             "CNTY_FIPS": "037",
#             "FIPS": "27037",
#             "NUM_LICENSED_BEDS": 57,
#             "NUM_STAFFED_BEDS": 29,
#             "NUM_ICU_BEDS": 5,
#             "ADULT_ICU_BEDS": 5,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.2933396,
#             "Potential_Increase_In_Bed_Capac": 28,
#             "AVG_VENTILATOR_USAGE": 2
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 1994,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -93.2726656999999,
#                44.7489410000001
#             ]
#          },
#          "properties": {
#             "OBJECTID": 1994,
#             "HOSPITAL_NAME": "M Health Fairview Ridges Hospital",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "201 E Nicollet Blvd",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Burnsville",
#             "HQ_STATE": "MN",
#             "HQ_ZIP_CODE": "55337",
#             "COUNTY_NAME": "Dakota",
#             "STATE_NAME": "Minnesota",
#             "STATE_FIPS": "27",
#             "CNTY_FIPS": "037",
#             "FIPS": "27037",
#             "NUM_LICENSED_BEDS": 150,
#             "NUM_STAFFED_BEDS": 150,
#             "NUM_ICU_BEDS": 12,
#             "ADULT_ICU_BEDS": 12,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.6837139,
#             "Potential_Increase_In_Bed_Capac": 0,
#             "AVG_VENTILATOR_USAGE": 3
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 1995,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -95.376048,
#                45.8739484000001
#             ]
#          },
#          "properties": {
#             "OBJECTID": 1995,
#             "HOSPITAL_NAME": "Alomere Health (FKA Douglas County Hospital)",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "111 17th Ave E",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Alexandria",
#             "HQ_STATE": "MN",
#             "HQ_ZIP_CODE": "56308",
#             "COUNTY_NAME": "Douglas",
#             "STATE_NAME": "Minnesota",
#             "STATE_FIPS": "27",
#             "CNTY_FIPS": "041",
#             "FIPS": "27041",
#             "NUM_LICENSED_BEDS": 127,
#             "NUM_STAFFED_BEDS": 99,
#             "NUM_ICU_BEDS": 8,
#             "ADULT_ICU_BEDS": 8,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.2963609,
#             "Potential_Increase_In_Bed_Capac": 28,
#             "AVG_VENTILATOR_USAGE": 3
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 1996,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -94.1003767999999,
#                43.6341659
#             ]
#          },
#          "properties": {
#             "OBJECTID": 1996,
#             "HOSPITAL_NAME": "United Hospital District",
#             "HOSPITAL_TYPE": "Critical Access Hospital",
#             "HQ_ADDRESS": "515 S Moore St",
#             "HQ_ADDRESS1": "PO BOX 160",
#             "HQ_CITY": "Blue Earth",
#             "HQ_STATE": "MN",
#             "HQ_ZIP_CODE": "56013",
#             "COUNTY_NAME": "Faribault",
#             "STATE_NAME": "Minnesota",
#             "STATE_FIPS": "27",
#             "CNTY_FIPS": "043",
#             "FIPS": "27043",
#             "NUM_LICENSED_BEDS": 43,
#             "NUM_STAFFED_BEDS": 24,
#             "NUM_ICU_BEDS": 4,
#             "ADULT_ICU_BEDS": 4,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.3555936,
#             "Potential_Increase_In_Bed_Capac": 19,
#             "AVG_VENTILATOR_USAGE": 1
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 1997,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -93.3730619999999,
#                43.6524998
#             ]
#          },
#          "properties": {
#             "OBJECTID": 1997,
#             "HOSPITAL_NAME": "Mayo Clinic Hospital - Albert Lea",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "404 W Fountain St",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Albert Lea",
#             "HQ_STATE": "MN",
#             "HQ_ZIP_CODE": "56007",
#             "COUNTY_NAME": "Freeborn",
#             "STATE_NAME": "Minnesota",
#             "STATE_FIPS": "27",
#             "CNTY_FIPS": "047",
#             "FIPS": "27047",
#             "NUM_LICENSED_BEDS": 159,
#             "NUM_STAFFED_BEDS": 159,
#             "NUM_ICU_BEDS": 18,
#             "ADULT_ICU_BEDS": 18,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.251624,
#             "Potential_Increase_In_Bed_Capac": 0,
#             "AVG_VENTILATOR_USAGE": 4
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 1998,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -92.5719670999999,
#                44.5600031000001
#             ]
#          },
#          "properties": {
#             "OBJECTID": 1998,
#             "HOSPITAL_NAME": "Mayo Clinic Hospital - Red Wing (FKA Fairview Red Wing Hospital)",
#             "HOSPITAL_TYPE": "Short Term Acute Care Hospital",
#             "HQ_ADDRESS": "701 Hewitt Blvd",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Red Wing",
#             "HQ_STATE": "MN",
#             "HQ_ZIP_CODE": "55066",
#             "COUNTY_NAME": "Goodhue",
#             "STATE_NAME": "Minnesota",
#             "STATE_FIPS": "27",
#             "CNTY_FIPS": "049",
#             "FIPS": "27049",
#             "NUM_LICENSED_BEDS": 50,
#             "NUM_STAFFED_BEDS": 50,
#             "NUM_ICU_BEDS": 4,
#             "ADULT_ICU_BEDS": 4,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.2567671,
#             "Potential_Increase_In_Bed_Capac": 0,
#             "AVG_VENTILATOR_USAGE": 2
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 1999,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -92.9032936999999,
#                44.4861339
#             ]
#          },
#          "properties": {
#             "OBJECTID": 1999,
#             "HOSPITAL_NAME": "Mayo Clinic Hospital - Cannon Falls",
#             "HOSPITAL_TYPE": "Critical Access Hospital",
#             "HQ_ADDRESS": "32021 County 24 Blvd",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Cannon Falls",
#             "HQ_STATE": "MN",
#             "HQ_ZIP_CODE": "55009",
#             "COUNTY_NAME": "Goodhue",
#             "STATE_NAME": "Minnesota",
#             "STATE_FIPS": "27",
#             "CNTY_FIPS": "049",
#             "FIPS": "27049",
#             "NUM_LICENSED_BEDS": 15,
#             "NUM_STAFFED_BEDS": 15,
#             "NUM_ICU_BEDS": 5,
#             "ADULT_ICU_BEDS": 5,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.6089498,
#             "Potential_Increase_In_Bed_Capac": 0,
#             "AVG_VENTILATOR_USAGE": 2
#          }
#       },
#       {
#          "type": "Feature",
#          "id": 2000,
#          "geometry": {
#             "type": "Point",
#             "coordinates": [
#                -95.9578332,
#                45.9908182
#             ]
#          },
#          "properties": {
#             "OBJECTID": 2000,
#             "HOSPITAL_NAME": "Prairie Ridge Hospital and Health Services",
#             "HOSPITAL_TYPE": "Critical Access Hospital",
#             "HQ_ADDRESS": "1411 State Hgwy 79 East",
#             "HQ_ADDRESS1": null,
#             "HQ_CITY": "Elbow Lake",
#             "HQ_STATE": "MN",
#             "HQ_ZIP_CODE": "56531",
#             "COUNTY_NAME": "Grant",
#             "STATE_NAME": "Minnesota",
#             "STATE_FIPS": "27",
#             "CNTY_FIPS": "051",
#             "FIPS": "27051",
#             "NUM_LICENSED_BEDS": 10,
#             "NUM_STAFFED_BEDS": 10,
#             "NUM_ICU_BEDS": 2,
#             "ADULT_ICU_BEDS": 2,
#             "PEDI_ICU_BEDS": 0,
#             "BED_UTILIZATION": 0.1717808,
#             "Potential_Increase_In_Bed_Capac": 0,
#             "AVG_VENTILATOR_USAGE": 0
#          }
#       }
#    ]
# }
